# %%
import pandas as pd

# %%
df=pd.read_excel('BINGO2 100520 - 1990-2015.xlsx')

# %%
df
# Out:
#           id                 ingos  year    country  operationsblend  \
# 0          1  Accion International  2007  Argentina                2
# 1          2  Accion International  2008  Argentina                2
# 2          3  Accion International  2009  Argentina                2
# 3          4  Accion International  2010  Argentina                2
# 4          5  Accion International  2001      Benin                2
# ...      ...                   ...   ...        ...              ...
# 86859  86860     ZOA International  2015     Uganda                2
# 86860  86861     ZOA International  2012      Yemen                1
# 86861  86862     ZOA International  2013      Yemen                1
# 86862  86863     ZOA International  2014      Yemen                1
# 86863  86864     ZOA International  2015      Yemen                1
#
#        sourceblend  FIODI  DSIODI  DSIAI  operationsconfidence  \
# 0                0      1       0      0                   1.0
# ...

# %%
duplicatedf = df[df.duplicated()]
print("Df duplicate rows except first occurrence based on all columns are :")
print(duplicatedf)
# Out:
# Df duplicate rows except first occurrence based on all columns are :
# Empty DataFrame
# Columns: [id, ingos, year, country, operationsblend, sourceblend, FIODI, DSIODI, DSIAI, operationsconfidence, sourceconfidence]
# Index: []

# %%
'''created in the country-year set based on the attached INGO set:

 

·         Ingo_count – total count of INGOs in the country-year (anything with ops or source greater than 0)

·         FIODI_count – total number of FIODI in country-year

·         DSIODI_count – total number of DSIODI in country-year'''

# %%
from collections import Counter

# %%
dict(Counter(df.operationsblend))   ##check values for columns
#dict(Counter(df.sourceblend))
# Out:
# {2: 62934, 0: 4068, 1: 19862}

# %%
df1=df.iloc[:, 1:6]

# %%
df1=df1.query('operationsblend >0 or sourceblend >0')

# %%
df1
# Out:
#                       ingos  year    country  operationsblend  sourceblend
# 0      Accion International  2007  Argentina                2            0
# 1      Accion International  2008  Argentina                2            0
# 2      Accion International  2009  Argentina                2            0
# 3      Accion International  2010  Argentina                2            0
# 4      Accion International  2001      Benin                2            0
# ...                     ...   ...        ...              ...          ...
# 86859     ZOA International  2015     Uganda                2            1
# 86860     ZOA International  2012      Yemen                1            0
# 86861     ZOA International  2013      Yemen                1            0
# 86862     ZOA International  2014      Yemen                1            0
# 86863     ZOA International  2015      Yemen                1            0
#
# [86851 rows x 5 columns]

# %%
df2=df1.iloc[:, 0:3]

# %%
df2
# Out:
#                       ingos  year    country
# 0      Accion International  2007  Argentina
# 1      Accion International  2008  Argentina
# 2      Accion International  2009  Argentina
# 3      Accion International  2010  Argentina
# 4      Accion International  2001      Benin
# ...                     ...   ...        ...
# 86859     ZOA International  2015     Uganda
# 86860     ZOA International  2012      Yemen
# 86861     ZOA International  2013      Yemen
# 86862     ZOA International  2014      Yemen
# 86863     ZOA International  2015      Yemen
#
# [86851 rows x 3 columns]

# %%
duplicatedf2 = df2[df2.duplicated()]
print("Duplicate INGOs except first occurrence based on all columns are :")
print(duplicatedf2)
# Out:
# Duplicate Rows except first occurrence based on all columns are :
#                                                    ingos  year  \
# 20738                               Doctors of the World  2015
# 31002                                      Global Voices  2008
# 39892                                International Alert  2008
# 55413  International Rehabilitation Council for Tortu...  2002
# 56088                     International Rescue Committee  2002
# 56090                     International Rescue Committee  2003
# 56092                     International Rescue Committee  2004
# 56094                     International Rescue Committee  2005
# 56100                     International Rescue Committee  2010
# 61089                          Norwegian Refugee Council  2014
# 61278                          Norwegian Refugee Council  2002
# 61716                          Norwegian Refugee Council  2003
# 61717                          Norwegian Refugee Council  2004
# ...

# %%
newdf2=df2[~df2.duplicated()]

# %%
newdf2
# Out:
#                       ingos  year    country
# 0      Accion International  2007  Argentina
# 1      Accion International  2008  Argentina
# 2      Accion International  2009  Argentina
# 3      Accion International  2010  Argentina
# 4      Accion International  2001      Benin
# ...                     ...   ...        ...
# 86859     ZOA International  2015     Uganda
# 86860     ZOA International  2012      Yemen
# 86861     ZOA International  2013      Yemen
# 86862     ZOA International  2014      Yemen
# 86863     ZOA International  2015      Yemen
#
# [86821 rows x 3 columns]

# %%
Ingo_count=newdf2.groupby(['year','country']).count()

# %%
Ingo_count
# Out:
#                           ingos
# year country
# 1990 Afghanistan             16
#      Albania                  4
#      Algeria                  7
#      Angola                  12
#      Antigua and Barbuda      4
# ...                         ...
# 2015 Venezuela               19
#      Vietnam                 38
#      Yemen                   27
#      Zambia                  49
#      Zimbabwe                43
#
# [4960 rows x 1 columns]

# %%
Ingo_count.rename(columns = {'ingos':'Ingo_count'}, inplace = True) #rename column

# %%
Ingo_count.reset_index()
# Out:
#       year              country  Ingo_count
# 0     1990          Afghanistan          16
# 1     1990              Albania           4
# 2     1990              Algeria           7
# 3     1990               Angola          12
# 4     1990  Antigua and Barbuda           4
# ...    ...                  ...         ...
# 4955  2015            Venezuela          19
# 4956  2015              Vietnam          38
# 4957  2015                Yemen          27
# 4958  2015               Zambia          49
# 4959  2015             Zimbabwe          43
#
# [4960 rows x 3 columns]

# %%
''' FIODI_count – total number of FIODI in country-year''' #check if there's dups in df2

# %%
df3=df[['year','country','ingos','FIODI']]
df3=df3[~df3.duplicated()]

# %%
df3   ###%851-838=13 dups
# Out:
#        year    country                 ingos  FIODI
# 0      2007  Argentina  Accion International      1
# 1      2008  Argentina  Accion International      1
# 2      2009  Argentina  Accion International      1
# 3      2010  Argentina  Accion International      1
# 4      2001      Benin  Accion International      1
# ...     ...        ...                   ...    ...
# 86859  2015     Uganda     ZOA International      0
# 86860  2012      Yemen     ZOA International      1
# 86861  2013      Yemen     ZOA International      1
# 86862  2014      Yemen     ZOA International      1
# 86863  2015      Yemen     ZOA International      1
#
# [86838 rows x 4 columns]

# %%
df4=df3.groupby(['year', 'country'])['FIODI'].count()
df4.reset_index()
# Out:
#       year              country  FIODI
# 0     1990          Afghanistan     16
# 1     1990              Albania      4
# 2     1990              Algeria      7
# 3     1990               Angola     12
# 4     1990  Antigua and Barbuda      4
# ...    ...                  ...    ...
# 4955  2015            Venezuela     19
# 4956  2015              Vietnam     38
# 4957  2015                Yemen     27
# 4958  2015               Zambia     49
# 4959  2015             Zimbabwe     43
#
# [4960 rows x 3 columns]

# %%
df4.columns = ['year', 'country', 'FIODI_count']

# %%
''' DSIODI_count – total number of DSIODI in country-year'''

# %%
df5=df[['year','country','ingos','DSIODI']]

# %%
df5=df5[~df5.duplicated()]
df5
# Out:
#        year    country                 ingos  DSIODI
# 0      2007  Argentina  Accion International       0
# 1      2008  Argentina  Accion International       0
# 2      2009  Argentina  Accion International       0
# 3      2010  Argentina  Accion International       0
# 4      2001      Benin  Accion International       0
# ...     ...        ...                   ...     ...
# 86859  2015     Uganda     ZOA International       1
# 86860  2012      Yemen     ZOA International       0
# 86861  2013      Yemen     ZOA International       0
# 86862  2014      Yemen     ZOA International       0
# 86863  2015      Yemen     ZOA International       0
#
# [86838 rows x 4 columns]

# %%
df6=df5.groupby(['year', 'country'])['DSIODI'].count().reset_index()

# %%
df6.columns = ['year', 'country', 'DSIODI_count']

# %%
'''DSIAI_count – total number of DSIAI in country-year'''

# %%
df7=df[['year','country','ingos','DSIAI']]
df7=df7[~df7.duplicated()]
df7
# Out:
#        year    country                 ingos  DSIAI
# 0      2007  Argentina  Accion International      0
# 1      2008  Argentina  Accion International      0
# 2      2009  Argentina  Accion International      0
# 3      2010  Argentina  Accion International      0
# 4      2001      Benin  Accion International      0
# ...     ...        ...                   ...    ...
# 86859  2015     Uganda     ZOA International      0
# 86860  2012      Yemen     ZOA International      0
# 86861  2013      Yemen     ZOA International      0
# 86862  2014      Yemen     ZOA International      0
# 86863  2015      Yemen     ZOA International      0
#
# [86834 rows x 4 columns]

# %%
df8=df7.groupby(['year', 'country'])['DSIAI'].count().reset_index()

# %%
df8.columns = ['year', 'country', 'DSIAI_count']
df8
# Out:
#       year              country  DSIAI_count
# 0     1990          Afghanistan           16
# 1     1990              Albania            4
# 2     1990              Algeria            7
# 3     1990               Angola           12
# 4     1990  Antigua and Barbuda            4
# ...    ...                  ...          ...
# 4955  2015            Venezuela           19
# 4956  2015              Vietnam           38
# 4957  2015                Yemen           27
# 4958  2015               Zambia           49
# 4959  2015             Zimbabwe           43
#
# [4960 rows x 3 columns]
